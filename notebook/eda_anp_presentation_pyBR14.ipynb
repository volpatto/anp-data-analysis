# %% [markdown]
# # Exploratory Data Analysis
#
# <p align="center">
#   <img src=img/pybr14.png" width="300"/></p>
#
# ---
#
# Let's begin our exploration over the [ANP public data base](http://www.anp.gov.br/dados-estatisticos)!
#
# The study that will follows are done (actually work in progress) by:
#
# * **Diego T. Volpatto**: DSc. student, MSc., Numerical Developer.
# * **Eduardo Bürgel**:  MSc., Software Developer.
#
# We working for [Engineering Simulation and Scientific Software](https://www.esss.co/), a multinational company lead at creation and customization of engineering simulation software.
#
# <p align="center">
#   <img src=img/esss_2_pos_RGB.jpg" width="400"/></p>

# %% [markdown]
# By the way:
#
# * We are doing the present analysis in our free time (not related to our job)
#
#
# * ESSS is hiring. If you have interest, come talk to me after the presentation!

# %% [markdown]
# ## What we want to do?
#
# * We want to answer some questions! But ANP did it already, but not entirely!
#
# * The better way to telling a story is throught the data. Better saying, doing an Exploratory Data Analysis! Putting it simple, it means know your data and potential parts at best.
#
# * From the data, what kind of study we can employ? Is it worthy? What we can retrieve from the data?

# %% [markdown]
# ## Brazilian Petroleum data
#
# * The data base provided by ANP is open, but treats only a general vision
#
# * In portuguese, we like to say: "Dados nunca são dados"!
#
# * Also, data gives to us knowledge (Yes, POWER!)
#
# * We want to explore the petroleum data within an integrated framework:
#     - Geospatial visualization
#     - Data Analysis
#
# * This kind of view is NATURAL in Petroleum workflow.

# %% [markdown]
# ## What we will need?!
#
# * Data base: ANP website
#
# * Data Analysis tool: pandas
#
# * Maps: Folium
#
# * Visualization libs: Matplotlib, Seaborn and Altair
#
# * Handling with geospatial data: Geopandas
#
# All Open Source and Free, waiting you to pick up them!

# %% [markdown]
# # Agenda
#
# * Introduction:
#     - A short overview of how to handle Excel files (common in companies over the world) with pandas
#     - How to construct maps with 4 lines of codes
#
# * A more significative application: Pre-salt data:
#     - We will draw a cool map
#     - Plot significant data in the map
#     - At last, a glimpse in most interesting data to Petroleum Engineers

# %% [markdown]
# # An Overview: Introduction

# %% [markdown]
# Opening an Excel file is pretty simple!

# %%
import pandas as pd

dfs = pd.read_excel('../data/tabela_de_pocos_abril_2018.xlsx', sheet_name='Plan1')

# %% [markdown]
# Now we fill a data field which we may need

# %%
dfs['TESTE_DE_FORMACAO'].fillna(value='Desconhecido', inplace=True)

# %% [markdown]
# ### Looking for a specific field: Albacora Leste

# %% [markdown]
# Let's get data from Albacora Leste field. The data must be:
#
# * Campo: Albacora Leste
# * Tipo: Explotatório
# * Categoria: Devenvolvimento
#
# Before looking for some data gathering and filtering, I will define some auxiliary functions.

# %%
def write_xlsx(file_name, dfs, sheetname='Plan1'):
    """
    Writes a data frame dfs in the file 'file_name.xlsx' with sheet name as 'sheetname'
    """ 
    #... Criando os arquivos excel
    writer = pd.ExcelWriter('%s.xlsx' % file_name)
    #... Convertendo o DataFrame para xlsx
    dfs.to_excel(writer,sheet_name=sheetname,index=False)
    #... Escrevendo os arquivos
    writer.save()
    
    
def write_reduced_xlsx(
    file_name,
    dfs,
    columns_fmt=['POCO','CADASTRO,CAMPO','SITUACAO','CATEGORIA'],
    sheetname='Plan1'
):
    """
    Write, in a reduced fashion, the data frame 'dfs' in a file named file_name.xlsx with sheet name as 'sheetname'.
    The reduced format is given by 'columns_fmt'.
    """ 
    dfs_reduced = dfs[columns_fmt]
    writer_reduced = pd.ExcelWriter('%s.xlsx' % file_name)
    dfs_reduced.to_excel(writer_reduced, sheet_name=sheetname, index=False)
    writer_reduced.save()

# %%
# %%time
nome_campo = 'ALBACORA LESTE'
filter1 = dfs['CAMPO']==nome_campo
filter1 &= dfs['TIPO']==u'Explotatório'
filter1 &= dfs['CATEGORIA']=='Desenvolvimento'
candidatos = dfs[filter1]
colunas_principais = ['CAMPO', 'SITUACAO', 'CATEGORIA', 'RECLASSIFICACAO', 'TESTE_DE_FORMACAO']

#... Escrevendo os pocos candidatos possíveis

principais_cols = ['POCO','CADASTRO','OPERADOR','ESTADO','BACIA','CAMPO','TERRA_MAR','SITUACAO','CATEGORIA', 'RECLASSIFICACAO', 'TESTE_DE_FORMACAO','PROFUNDIDADE_MEDIDA_M','DIRECAO','TESTEMUNHO']
write_xlsx('../out/pocos_ABL', candidatos)
write_reduced_xlsx('../out/pocos_ABL_resumido', candidatos, principais_cols)
# Out:
# CPU times: user 305 ms, sys: 12 µs, total: 305 ms
# Wall time: 308 ms

# %% [markdown]
# Now, suppose we need the producting wells. So, I will filter them. But we need some functions before, provided below:

# %%
def get_produtors(dfs, field_name):
    '''
    Filters producting wells in a field
    '''
    productor = dfs[(dfs['CAMPO']==field_name) & (dfs['TIPO']==u'Explotatório') & (dfs['SITUACAO']=='PRODUZINDO') & \
            (dfs['CATEGORIA']=='Desenvolvimento') & (dfs['RECLASSIFICACAO']==u'PRODUTOR COMERCIAL DE PETRÓLEO')]
    productor.reset_index(inplace=True)
    return productor

# %% [markdown]
# Or the injection wells:

# %%
def get_injections(dfs, field_name):
    '''
    Filters the injection wells in a field
    '''
    injector = dfs[(dfs['CAMPO']==field_name) & (dfs['TIPO']==u'Explotatório') & (dfs['SITUACAO']=='INJETANDO') & \
            (dfs['CATEGORIA']==u'Injeção') & (dfs['RECLASSIFICACAO']==u'INJEÇÃO DE ÁGUA')]
    injector.reset_index(inplace=True)
    return injector

# %% [markdown]
# Now, we can get those guys:

# %%
# %%time
produtor = get_produtors(dfs, nome_campo)

#... Escrevendo os pocos produtores possíveis

principais_cols = ['POCO','CADASTRO','BACIA','CAMPO','TERRA_MAR','SITUACAO','CATEGORIA','RECLASSIFICACAO', 'LATITUDE_BASE_DD', 'LONGITUDE_BASE_DD','PROFUNDIDADE_MEDIDA_M','DIRECAO']
write_xlsx('../out/pocos_produtores_ABL', produtor)
write_reduced_xlsx('../out/pocos_produtores_resumido_ABL',produtor, principais_cols)

#... Filtrando um poço injetor nas condições adequadas de produção

injetor = get_injections(dfs, nome_campo)

#... Escrevendo os pocos produtores possíveis

write_xlsx('../out/pocos_injetores_ABL', injetor)
write_reduced_xlsx('../out/pocos_injetores_resumido_ABL', injetor, principais_cols)
# Out:
# CPU times: user 217 ms, sys: 4.01 ms, total: 221 ms
# Wall time: 220 ms

# %% [markdown]
# ## Let's draw some maps?
#
# Do you know [Folium?](https://github.com/python-visualization/folium) It's a very good Python lib which bring to us
# the Leaflet.js in our beloved programming language.
#
# Best of JS with pleasure from Python! The main maintainer is brazilian!
#
# Let's take a look...

# %%
import folium

# %% [markdown]
# Providing the coordinates and the zoom factor, we can plot a map within 4 lines!

# %%
def create_folium_map(lat, lot, zfact):
    '''
    Cria um objeto Folium.Map do tipo OpenStreetMap centrado em (lat,lot) com nível de zoom zfact
    '''
    import folium
    tiles = 'http://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
    attr = ('Tiles &copy; Esri &mdash; Sources: GEBCO, NOAA, CHS, OSU, UNH, CSUMB, National Geographic, DeLorme, NAVTEQ, and Esri')
    m = folium.Map(location=[lat,lot], 
            tiles=tiles,
            attr=attr,
            zoom_start=zfact)
    return m

# %%
m = create_folium_map(-22.0,-40.0,8)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I want to add some wells at my map. So let's create a function to this duty.

# %%
def add_pocos_mapa(mapa, pocos, cor, kind=1, nome_grupo=u'default'):
    if kind != 1 and kind != 2:
        print("Erro: Tipo de marcação no mapa indisponível!")
        return False
    else:
        pocos_len = pocos.shape[0]
        grupo = folium.FeatureGroup(nome_grupo)
        for i in range(pocos_len):
            lat, lont = float(pocos['LATITUDE_BASE_DD'][i].replace(",",".")), float(pocos['LONGITUDE_BASE_DD'][i].replace(",","."))
            if kind==1:
                folium.Marker(
                    location=[lat, lont],
                    popup=pocos['POCO'][i],
                    icon=folium.Icon(color=cor),
                    ).add_to(grupo)
            if kind==2:
                folium.Circle(
                    location=[lat, lont],
                    popup=pocos['POCO'][i],
                    radius=15,
                    color='red',
                    fill=True,
                    fill_color='crimson'
                    ).add_to(grupo)
            grupo.add_to(mapa)

# %% [markdown]
# Now we put the guys right on the map!

# %% [markdown]
# Productors Wells

# %%
add_pocos_mapa(
    m,
    produtor,
    'red',
    nome_grupo=(produtor['CAMPO'][0]+" ("+produtor['SITUACAO'][0]+")")
)

# %% [markdown]
# Injection Wells

# %%
add_pocos_mapa(
    m, 
    injetor,
    'blue',
    nome_grupo=(injetor['CAMPO'][0]+" ("+injetor['SITUACAO'][0]+")")
)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Folium and Geopandas

# %% [markdown]
# What if we can use geospatial data such as shp files? [Geopandas](http://geopandas.org/) extends pandas capability to incorporate geospatial data to allow spatial operations over geometric types.

# %%
import geopandas as gp

# %% [markdown]
# Without dive-in in details, let's see how it works.
#
# The function below adds multiples shp components over a provided map:

# %%
def add_multi_shp(mapa, nome_shp, cor='ffff00'):
    fp = '%s.shp' % nome_shp
    data = gp.read_file(fp)
    data_range = data.shape[0]
    for i in range(data_range):
        shp_plot = folium.GeoJson(
                data.iloc[i:i+1],
                name=(u'Campo: %s' %  data['NOM_CAMPO'][i].lower()), 
                style_function=lambda feature: {
                    'fillColor': cor,
                    'color': 'black',
                    'weight': 2,
                    'dashArray': '5, 5'
                }
        )
        label = '%s' % data['NOM_CAMPO'][i]
        folium.Popup(label).add_to(shp_plot)
        shp_plot.add_to(mapa)

# %% [markdown]
# Now we can add ALL the data provided by ANP about geospatial coordinates of petroleum fields in our map:

# %%
add_multi_shp(m, '../Campos/Campos_de_Producao', cor='red')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Enjoying our exploration so far?
#
# Because the true exploration will begin right now!

# %% [markdown]
# # Pre-salt Data
#
# * Brazil is a very rich country in natural resources, petroleum included.
#
# * We have a large amount of pre-salt in our territory
#
# * Technology is been studied to improve pre-salt production
#
# * Approximately half of our national production comes from Pre-salt
#
# * Pre-salt is just in the beginning!
#
# * Quite interesting! Let's take a look.

# %% [markdown]
# ## Preprocessing pre-salt wells data

# %% [markdown]
# Preprocessing the pre-salt wells data files is the first step, but I will skip the details.
#
# The data base file are `.xls` or `.xlsx`, two header's possibility to the similar informations. Check by yourself and enjoy multi-index pandas trip!
#
# One can check this full notebook on my GitHub ([https://github.com/volpatto/anp-data-analysis](https://github.com/volpatto/anp-data-analysis)) for further details.

# %%
import numpy as np
import pandas as pd

from os import walk
from unicodedata import normalize

files = []
for (dirpath, dirnames, filenames) in walk('../data/producao-por-poco'):
    for filename in filenames:
        if filename.startswith('presal') or filename.endswith('presal.xls') or filename.endswith('presal.xlsx'):
            files.append('%s/%s' % (dirpath, filename))

wells = []
for file in sorted(files):
    excel_file = pd.read_excel(file)
    initial_column = excel_file.columns[0]

    period_value = None
    well_data = None
    production_data = None
    try:
        if initial_column.startswith('ANP - Agência Nacional do Petroleo'):
            data = pd.read_excel(file, skiprows=4, header=[0, 1], index_col=None)

            period = data.xs('Período', axis=1, level=0, drop_level=True).iloc[:, 0]
            period = period.dropna().unique()
            period = period[0].replace('/', '_')

            production_col = None
            field_col = None
            for column in data.columns:
                if column[0].startswith('Petróleo (bbl/dia)'):
                    production_col = column
                if column[0].startswith('Campo'):
                    field_col = column
            selected_data = data[[('Nome Poço', 'ANP'), field_col, production_col]]

            period_value = period
            well_data = selected_data[('Nome Poço', 'ANP')].values
            field_data = selected_data[field_col].values
            production_data = selected_data[production_col].values

        elif initial_column.startswith('COD_POCO') or initial_column.startswith('NOM_POCO_ANP'):
            data = pd.read_excel(file)

            period = data['PERIODO'].dropna().unique()
            period = period[0].replace('-', '_')

            selected_data = data[['NOM_POCO_ANP', 'NOM_CAMPO', 'OLEO_BBL_DIA']]

            well_data = pd.DataFrame(columns=['well', 'production_%s' % period])

            period_value = period
            well_data = data['NOM_POCO_ANP'].values
            field_data = data['NOM_CAMPO'].values
            production_data = data['OLEO_BBL_DIA'].values

    except Exception as exc:
        print('********** Exception **********', exc)

    well_df = pd.DataFrame(columns=['well', 'field', 'prod_%s' % period])
    well_df['well'] = well_data
    well_df['field'] = field_data
    well_df['prod_%s' % period] = pd.to_numeric(production_data)

    # Remove nan in well index.
    well_df = well_df.drop(well_df.loc[well_df.well.isnull()].index, axis=0)
    # Remove nan in field index.
    well_df = well_df.drop(well_df.loc[well_df.field.isnull()].index, axis=0)
    # Remove description index.
    well_df = well_df.drop(well_df.loc[well_df.well.map(len) > 50].index, axis=0)

    well_df.well = well_df.well.map(str.strip)
    well_df.well = well_df.well.map(str.lower)
    well_df.field = well_df.field.map(str.strip)
    well_df.field = well_df.field.map(str.lower)

    def normalize_str(input_str):
        return normalize('NFKD', input_str).encode('ascii', 'ignore').decode('utf-8')
    well_df.well = well_df.well.map(normalize_str)
    well_df.field = well_df.field.map(normalize_str)

    def replace_str(input_str):
        return input_str.replace(' ', '').replace('-', '')
    well_df.well = well_df.well.map(replace_str)
    well_df.field = well_df.field.map(replace_str)

    well_df['index'] = well_df.apply(lambda row: '%s_%s' % (row['well'], row['field']), axis=1)

    well_df = well_df.drop('well', axis=1)
    well_df = well_df.drop('field', axis=1)
    well_df = well_df.set_index('index')

    well_df = well_df[~well_df.index.duplicated(keep='first')]

    wells.append(well_df)

salt_df = pd.concat(wells, axis=1)
salt_df
# Out:
# /home/diego/anaconda3/envs/eda-anp/lib/python3.6/site-packages/ipykernel_launcher.py:98: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                            prod_2016_01  prod_2016_02  prod_2016_03  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN     4038.4289           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     3217.8084      940.7094     1039.1168
# 3brsa1053rjs_buzios           3444.0484    13159.8767       20.1903
# 3brsa1054drjs_marlimleste     3089.7979     3020.2906     3049.9899
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero                  NaN           NaN           NaN
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             21806.3831    21900.5478    22259.9048
# 3brsa788sps_sapinhoa         25972.5761    20186.7470    15274.7232
# 3brsa821rjs_lula                    NaN           NaN     2012.6820
# 3brsa830rjs_lula                    NaN           NaN           NaN
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula                      NaN           NaN           NaN
# 8lpa2dsps_lapa                      NaN           NaN           NaN
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                 412.9565      395.4946           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             22103.1498    22207.9325    22361.7354
# 9brsa908drjs_lula            13856.5582    13533.3875    13417.0412
# 9brsa928sps_sapinhoa          6484.2449    10367.1932    24688.8344
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula                      NaN    24150.7969    32948.5508
# 9ll19rjs_lula                25174.7099    23005.6134     7030.1326
# 9ll20drjs_lula               27981.0206    22378.0029    26645.4111
# 9ll2rjs_lula                 28186.6944    33315.4448    29282.1853
# 9ll6arjs_lula                24746.3310    20402.5434    22622.2979
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_04  prod_2016_05  prod_2016_06  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN    16793.2997    19357.6807
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     1645.0457     1578.5540     1555.8059
# 3brsa1053rjs_buzios                 NaN     3389.5847           NaN
# 3brsa1054drjs_marlimleste      408.6213           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero                  NaN           NaN           NaN
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             10113.8224    18571.4009    21956.2511
# 3brsa788sps_sapinhoa         21989.9431    17651.8362    13338.3866
# 3brsa821rjs_lula                    NaN     4352.8143    11347.9087
# 3brsa830rjs_lula                    NaN    11202.3624    15316.2205
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula                      NaN           NaN           NaN
# 8lpa2dsps_lapa                      NaN           NaN           NaN
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             12456.0433    14567.2424     9401.5409
# 9brsa908drjs_lula             8202.8515    13082.2245    13146.4325
# 9brsa928sps_sapinhoa          2116.2395    14485.2884    22314.0839
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               32196.6184    33494.9688    33015.3630
# 9ll19rjs_lula                 9255.1860    17353.1954     9670.4214
# 9ll20drjs_lula               30788.5424    20002.4287    28179.6468
# 9ll2rjs_lula                 31070.9978    30334.7783    34322.7501
# 9ll6arjs_lula                29061.8352    16222.2626    20648.8869
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_07  prod_2016_08  prod_2016_09  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN      222.1723           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia            17324.6283    19303.0414      421.0546
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     1554.5046     1668.1607     1594.7409
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero                  NaN           NaN           NaN
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             22511.5325    20002.4388    21239.8556
# 3brsa788sps_sapinhoa         20088.7421    20518.7056    24938.9971
# 3brsa821rjs_lula              2481.2793    13555.1659    14471.0598
# 3brsa830rjs_lula             16289.3414    18387.9566    20330.7717
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN        0.0000        0.0000
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula                      NaN           NaN           NaN
# 8lpa2dsps_lapa                      NaN           NaN           NaN
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             15153.1996    13150.3592    13689.8673
# 9brsa908drjs_lula            13195.8227    13082.7589    12874.5697
# 9brsa928sps_sapinhoa         27081.4678    22586.5081    22128.8557
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios               3759.2165    15098.0802    13195.5643
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               33048.6822    27500.6023    30051.4519
# 9ll19rjs_lula                16278.5025           NaN    15932.2978
# 9ll20drjs_lula               25707.6662    16705.1910    28589.3346
# 9ll2rjs_lula                 32292.9629    32333.3934    28995.9882
# 9ll6arjs_lula                17332.8491    15499.6369    27829.5765
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_10      ...       prod_2017_11  \
# 1brsa108aess_jubarte             0.0000      ...                NaN
# 1brsa1116rjs_itapu               0.0000      ...         29251.1241
# 1brsa1146rjs_atapu               0.0000      ...                NaN
# 1brsa594sps_sapinhoa             0.0000      ...                NaN
# 1brsa976rjs_sepia                0.0000      ...                NaN
# 2anp1rjs_buzios                  0.0000      ...                NaN
# 3brsa1017drjs_marlimleste     1728.0598      ...          2677.8512
# 3brsa1053rjs_buzios              0.0000      ...                NaN
# 3brsa1054drjs_marlimleste        0.0000      ...                NaN
# 3brsa1064rjs_buzios              0.0000      ...                NaN
# 3brsa1132rjs_berbigao            0.0000      ...                NaN
# 3brsa1172rjs_atapu               0.0000      ...                NaN
# 3brsa1184rjs_buzios              0.0000      ...                NaN
# 3brsa1201rjs_sepia               0.0000      ...                NaN
# 3brsa1215rjs_itapu                  NaN      ...                NaN
# 3brsa1243rjs_oestedeatapu        0.0000      ...                NaN
# 3brsa1305arjs_mero                  NaN      ...          1516.0748
# 3brsa1350rjs_mero                   NaN      ...                NaN
# 3brsa496rjs_lula             15338.7192      ...         12370.6255
# 3brsa788sps_sapinhoa         23737.4376      ...         19046.3548
# 3brsa821rjs_lula              9567.5976      ...          1607.6832
# 3brsa830rjs_lula              9219.2716      ...                NaN
# 3brsa839arjs_lula                   NaN      ...         24300.5054
# 3brsa854rjs_lula                 0.0000      ...                NaN
# 3brsa861sps_lapa                 0.0000      ...                NaN
# 3brsa865arjs_lula                   NaN      ...         18352.5701
# 3brsa883rjs_lula                    NaN      ...         17422.3533
# 3li0001rjs_linguado              0.0000      ...                NaN
# 3pm0002rjs_pampo                 0.0000      ...                NaN
# 3pm0003arjs_pampo                0.0000      ...                NaN
# ...                                 ...      ...                ...
# 8ll87drjs_lula                      NaN      ...         27862.0554
# 8lpa2dsps_lapa                      NaN      ...                NaN
# 8srr1arjs_sururu                    NaN      ...                NaN
# 9atp1rjs_atapu                      NaN      ...                NaN
# 9atp3rjs_atapu                      NaN      ...                NaN
# 9bbg1drjs_berbigao                  NaN      ...                NaN
# 9brsa1191rjs_buzios              0.0000      ...                NaN
# 9brsa1192sps_lapa                   NaN      ...                NaN
# 9brsa1197rjs_buzios              0.0000      ...                NaN
# 9brsa1212rjs_sururu                 NaN      ...                NaN
# 9brsa1254rjs_sepia               0.0000      ...                NaN
# 9brsa1284rjs_atapu                  NaN      ...                NaN
# 9brsa716rjs_lula              6158.8184      ...          5407.0897
# 9brsa908drjs_lula            10880.6705      ...         15193.4711
# 9brsa928sps_sapinhoa         23042.3809      ...         24299.6083
# 9buz1rjs_buzios                  0.0000      ...                NaN
# 9buz2rjs_buzios                  0.0000      ...                NaN
# 9buz3rjs_buzios                  0.0000      ...                NaN
# 9buz4rjs_buzios              14071.0070      ...                NaN
# 9buz7rjs_buzios                     NaN      ...                NaN
# 9buz8rjs_buzios                     NaN      ...                NaN
# 9ll12drjs_lula               30394.3221      ...         25947.2408
# 9ll19rjs_lula                24999.0383      ...         23736.8318
# 9ll20drjs_lula               28668.0316      ...         27089.6900
# 9ll2rjs_lula                 29146.6555      ...         28104.4555
# 9ll6arjs_lula                28915.3956      ...                NaN
# 9ll7rjs_lula                 20663.9268      ...         24418.4775
# 9mrl231darjs_marlim                 NaN      ...                NaN
# 9mrl231darjs_voador                 NaN      ...                NaN
# 9sep1rjs_sepia                   0.0000      ...                NaN
#
#                            prod_2017_12  prod_2018_01  prod_2018_02  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu            3033.0093           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN           NaN           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     2858.4587     3107.4003     3024.9240
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero           10698.2748    13565.2473    16317.7729
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             12310.9461    17644.5019    19575.6865
# 3brsa788sps_sapinhoa         21639.3270    21270.4296    22947.5755
# 3brsa821rjs_lula                    NaN           NaN     1039.7364
# 3brsa830rjs_lula              6611.7629    13024.3930    13308.0096
# 3brsa839arjs_lula            22013.2643    21385.6117    22637.8695
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula            19532.3666    18739.6801    17245.4199
# 3brsa883rjs_lula              6001.4415    13722.6747    14830.7657
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula               25866.9739    28182.8523    33249.1707
# 8lpa2dsps_lapa               16159.4984    15372.4422    15667.2990
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN    12536.8313
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula                    NaN           NaN           NaN
# 9brsa908drjs_lula            15257.5456    13800.0921    13063.5528
# 9brsa928sps_sapinhoa         24766.3393    24759.1880    25459.3679
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               26011.9838    27709.8527    26068.4927
# 9ll19rjs_lula                23640.3462    24716.9728    21604.8484
# 9ll20drjs_lula               26340.0114    27673.1042    28382.5365
# 9ll2rjs_lula                 16614.6066    19425.7146    20662.3071
# 9ll6arjs_lula                       NaN           NaN           NaN
# 9ll7rjs_lula                 25477.6935    24427.0231    25898.1806
# 9mrl231darjs_marlim                 NaN      295.9543           NaN
# 9mrl231darjs_voador                 NaN      374.6876           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2018_03  prod_2018_04  prod_2018_05  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN           NaN           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     2992.8340     1745.1677      586.4773
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero           25573.9250    36085.0088    39918.0538
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             19839.9511    23429.9532    22949.3915
# 3brsa788sps_sapinhoa         22012.1845    22799.8014    22446.9169
# 3brsa821rjs_lula                    NaN      802.7104           NaN
# 3brsa830rjs_lula             10887.4580    13804.0623    17785.6288
# 3brsa839arjs_lula            13067.2893    24361.8760    20224.5773
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula            17271.5823    17171.4966    16427.3555
# 3brsa883rjs_lula              3408.9104    20257.4403    20945.1907
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula               30035.0603    32568.6917    33990.6955
# 8lpa2dsps_lapa               16418.9444    16836.2929    16365.4891
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu          16835.6686    16303.9633    16250.4201
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula                    NaN           NaN           NaN
# 9brsa908drjs_lula             8969.5635    12851.1737    13756.1606
# 9brsa928sps_sapinhoa         24854.0247    12323.0419    24126.2471
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN    10021.0972    31289.2016
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               21892.0467           NaN     4214.0613
# 9ll19rjs_lula                22121.5773    22905.7604    23914.3750
# 9ll20drjs_lula               27244.6381    17736.4786    27492.6855
# 9ll2rjs_lula                 21777.7290    22109.4912    27928.3609
# 9ll6arjs_lula                       NaN           NaN           NaN
# 9ll7rjs_lula                 25007.3577    25219.2997    20450.6119
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2018_06  prod_2018_07  prod_2018_08
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN           NaN           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste      711.2949      693.0370      504.9356
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero           40975.2165    38846.0388    38577.1779
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             19201.1114    18361.9418     8779.3012
# 3brsa788sps_sapinhoa         20288.2610    22026.1444    22940.4320
# 3brsa821rjs_lula              6425.4644    10911.4175    11128.9070
# 3brsa830rjs_lula              9968.7335     9785.9828           NaN
# 3brsa839arjs_lula            21094.7851    21319.0462    22895.9576
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula            16348.0217     6990.5675           NaN
# 3brsa883rjs_lula             20134.6714    21921.5043    17734.7075
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula               33712.1519    33488.4008    26807.2159
# 8lpa2dsps_lapa               17230.0959    17404.3527    17319.0202
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu          16109.0987     9332.5117     1595.7836
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula                    NaN           NaN        0.7436
# 9brsa908drjs_lula             7102.2727     6680.0087     4731.2235
# 9brsa928sps_sapinhoa         25250.3097    22351.3773    13561.8593
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios              32587.5664    29859.1118    24302.8012
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               10051.2931    18559.7068    24237.9594
# 9ll19rjs_lula                  174.1973           NaN           NaN
# 9ll20drjs_lula               27706.4638    28773.2396    28775.1491
# 9ll2rjs_lula                 24858.2009    17535.5583    23610.1937
# 9ll6arjs_lula                       NaN           NaN           NaN
# 9ll7rjs_lula                 25317.9550    24528.6581    23660.0620
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
# [179 rows x 32 columns]

# %% [markdown]
# Take a look on the preprocessed pre-salt data below

# %%
salt_df
# Out:
#                            prod_2016_01  prod_2016_02  prod_2016_03  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN     4038.4289           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     3217.8084      940.7094     1039.1168
# 3brsa1053rjs_buzios           3444.0484    13159.8767       20.1903
# 3brsa1054drjs_marlimleste     3089.7979     3020.2906     3049.9899
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero                  NaN           NaN           NaN
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             21806.3831    21900.5478    22259.9048
# 3brsa788sps_sapinhoa         25972.5761    20186.7470    15274.7232
# 3brsa821rjs_lula                    NaN           NaN     2012.6820
# 3brsa830rjs_lula                    NaN           NaN           NaN
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula                      NaN           NaN           NaN
# 8lpa2dsps_lapa                      NaN           NaN           NaN
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                 412.9565      395.4946           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             22103.1498    22207.9325    22361.7354
# 9brsa908drjs_lula            13856.5582    13533.3875    13417.0412
# 9brsa928sps_sapinhoa          6484.2449    10367.1932    24688.8344
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula                      NaN    24150.7969    32948.5508
# 9ll19rjs_lula                25174.7099    23005.6134     7030.1326
# 9ll20drjs_lula               27981.0206    22378.0029    26645.4111
# 9ll2rjs_lula                 28186.6944    33315.4448    29282.1853
# 9ll6arjs_lula                24746.3310    20402.5434    22622.2979
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_04  prod_2016_05  prod_2016_06  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN    16793.2997    19357.6807
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     1645.0457     1578.5540     1555.8059
# 3brsa1053rjs_buzios                 NaN     3389.5847           NaN
# 3brsa1054drjs_marlimleste      408.6213           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero                  NaN           NaN           NaN
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             10113.8224    18571.4009    21956.2511
# 3brsa788sps_sapinhoa         21989.9431    17651.8362    13338.3866
# 3brsa821rjs_lula                    NaN     4352.8143    11347.9087
# 3brsa830rjs_lula                    NaN    11202.3624    15316.2205
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula                      NaN           NaN           NaN
# 8lpa2dsps_lapa                      NaN           NaN           NaN
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             12456.0433    14567.2424     9401.5409
# 9brsa908drjs_lula             8202.8515    13082.2245    13146.4325
# 9brsa928sps_sapinhoa          2116.2395    14485.2884    22314.0839
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               32196.6184    33494.9688    33015.3630
# 9ll19rjs_lula                 9255.1860    17353.1954     9670.4214
# 9ll20drjs_lula               30788.5424    20002.4287    28179.6468
# 9ll2rjs_lula                 31070.9978    30334.7783    34322.7501
# 9ll6arjs_lula                29061.8352    16222.2626    20648.8869
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_07  prod_2016_08  prod_2016_09  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN      222.1723           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia            17324.6283    19303.0414      421.0546
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     1554.5046     1668.1607     1594.7409
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero                  NaN           NaN           NaN
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             22511.5325    20002.4388    21239.8556
# 3brsa788sps_sapinhoa         20088.7421    20518.7056    24938.9971
# 3brsa821rjs_lula              2481.2793    13555.1659    14471.0598
# 3brsa830rjs_lula             16289.3414    18387.9566    20330.7717
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN        0.0000        0.0000
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula                      NaN           NaN           NaN
# 8lpa2dsps_lapa                      NaN           NaN           NaN
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             15153.1996    13150.3592    13689.8673
# 9brsa908drjs_lula            13195.8227    13082.7589    12874.5697
# 9brsa928sps_sapinhoa         27081.4678    22586.5081    22128.8557
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios               3759.2165    15098.0802    13195.5643
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               33048.6822    27500.6023    30051.4519
# 9ll19rjs_lula                16278.5025           NaN    15932.2978
# 9ll20drjs_lula               25707.6662    16705.1910    28589.3346
# 9ll2rjs_lula                 32292.9629    32333.3934    28995.9882
# 9ll6arjs_lula                17332.8491    15499.6369    27829.5765
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_10      ...       prod_2017_11  \
# 1brsa108aess_jubarte             0.0000      ...                NaN
# 1brsa1116rjs_itapu               0.0000      ...         29251.1241
# 1brsa1146rjs_atapu               0.0000      ...                NaN
# 1brsa594sps_sapinhoa             0.0000      ...                NaN
# 1brsa976rjs_sepia                0.0000      ...                NaN
# 2anp1rjs_buzios                  0.0000      ...                NaN
# 3brsa1017drjs_marlimleste     1728.0598      ...          2677.8512
# 3brsa1053rjs_buzios              0.0000      ...                NaN
# 3brsa1054drjs_marlimleste        0.0000      ...                NaN
# 3brsa1064rjs_buzios              0.0000      ...                NaN
# 3brsa1132rjs_berbigao            0.0000      ...                NaN
# 3brsa1172rjs_atapu               0.0000      ...                NaN
# 3brsa1184rjs_buzios              0.0000      ...                NaN
# 3brsa1201rjs_sepia               0.0000      ...                NaN
# 3brsa1215rjs_itapu                  NaN      ...                NaN
# 3brsa1243rjs_oestedeatapu        0.0000      ...                NaN
# 3brsa1305arjs_mero                  NaN      ...          1516.0748
# 3brsa1350rjs_mero                   NaN      ...                NaN
# 3brsa496rjs_lula             15338.7192      ...         12370.6255
# 3brsa788sps_sapinhoa         23737.4376      ...         19046.3548
# 3brsa821rjs_lula              9567.5976      ...          1607.6832
# 3brsa830rjs_lula              9219.2716      ...                NaN
# 3brsa839arjs_lula                   NaN      ...         24300.5054
# 3brsa854rjs_lula                 0.0000      ...                NaN
# 3brsa861sps_lapa                 0.0000      ...                NaN
# 3brsa865arjs_lula                   NaN      ...         18352.5701
# 3brsa883rjs_lula                    NaN      ...         17422.3533
# 3li0001rjs_linguado              0.0000      ...                NaN
# 3pm0002rjs_pampo                 0.0000      ...                NaN
# 3pm0003arjs_pampo                0.0000      ...                NaN
# ...                                 ...      ...                ...
# 8ll87drjs_lula                      NaN      ...         27862.0554
# 8lpa2dsps_lapa                      NaN      ...                NaN
# 8srr1arjs_sururu                    NaN      ...                NaN
# 9atp1rjs_atapu                      NaN      ...                NaN
# 9atp3rjs_atapu                      NaN      ...                NaN
# 9bbg1drjs_berbigao                  NaN      ...                NaN
# 9brsa1191rjs_buzios              0.0000      ...                NaN
# 9brsa1192sps_lapa                   NaN      ...                NaN
# 9brsa1197rjs_buzios              0.0000      ...                NaN
# 9brsa1212rjs_sururu                 NaN      ...                NaN
# 9brsa1254rjs_sepia               0.0000      ...                NaN
# 9brsa1284rjs_atapu                  NaN      ...                NaN
# 9brsa716rjs_lula              6158.8184      ...          5407.0897
# 9brsa908drjs_lula            10880.6705      ...         15193.4711
# 9brsa928sps_sapinhoa         23042.3809      ...         24299.6083
# 9buz1rjs_buzios                  0.0000      ...                NaN
# 9buz2rjs_buzios                  0.0000      ...                NaN
# 9buz3rjs_buzios                  0.0000      ...                NaN
# 9buz4rjs_buzios              14071.0070      ...                NaN
# 9buz7rjs_buzios                     NaN      ...                NaN
# 9buz8rjs_buzios                     NaN      ...                NaN
# 9ll12drjs_lula               30394.3221      ...         25947.2408
# 9ll19rjs_lula                24999.0383      ...         23736.8318
# 9ll20drjs_lula               28668.0316      ...         27089.6900
# 9ll2rjs_lula                 29146.6555      ...         28104.4555
# 9ll6arjs_lula                28915.3956      ...                NaN
# 9ll7rjs_lula                 20663.9268      ...         24418.4775
# 9mrl231darjs_marlim                 NaN      ...                NaN
# 9mrl231darjs_voador                 NaN      ...                NaN
# 9sep1rjs_sepia                   0.0000      ...                NaN
#
#                            prod_2017_12  prod_2018_01  prod_2018_02  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu            3033.0093           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN           NaN           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     2858.4587     3107.4003     3024.9240
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero           10698.2748    13565.2473    16317.7729
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             12310.9461    17644.5019    19575.6865
# 3brsa788sps_sapinhoa         21639.3270    21270.4296    22947.5755
# 3brsa821rjs_lula                    NaN           NaN     1039.7364
# 3brsa830rjs_lula              6611.7629    13024.3930    13308.0096
# 3brsa839arjs_lula            22013.2643    21385.6117    22637.8695
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula            19532.3666    18739.6801    17245.4199
# 3brsa883rjs_lula              6001.4415    13722.6747    14830.7657
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula               25866.9739    28182.8523    33249.1707
# 8lpa2dsps_lapa               16159.4984    15372.4422    15667.2990
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN    12536.8313
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula                    NaN           NaN           NaN
# 9brsa908drjs_lula            15257.5456    13800.0921    13063.5528
# 9brsa928sps_sapinhoa         24766.3393    24759.1880    25459.3679
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               26011.9838    27709.8527    26068.4927
# 9ll19rjs_lula                23640.3462    24716.9728    21604.8484
# 9ll20drjs_lula               26340.0114    27673.1042    28382.5365
# 9ll2rjs_lula                 16614.6066    19425.7146    20662.3071
# 9ll6arjs_lula                       NaN           NaN           NaN
# 9ll7rjs_lula                 25477.6935    24427.0231    25898.1806
# 9mrl231darjs_marlim                 NaN      295.9543           NaN
# 9mrl231darjs_voador                 NaN      374.6876           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2018_03  prod_2018_04  prod_2018_05  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN           NaN           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     2992.8340     1745.1677      586.4773
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero           25573.9250    36085.0088    39918.0538
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             19839.9511    23429.9532    22949.3915
# 3brsa788sps_sapinhoa         22012.1845    22799.8014    22446.9169
# 3brsa821rjs_lula                    NaN      802.7104           NaN
# 3brsa830rjs_lula             10887.4580    13804.0623    17785.6288
# 3brsa839arjs_lula            13067.2893    24361.8760    20224.5773
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula            17271.5823    17171.4966    16427.3555
# 3brsa883rjs_lula              3408.9104    20257.4403    20945.1907
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula               30035.0603    32568.6917    33990.6955
# 8lpa2dsps_lapa               16418.9444    16836.2929    16365.4891
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu          16835.6686    16303.9633    16250.4201
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula                    NaN           NaN           NaN
# 9brsa908drjs_lula             8969.5635    12851.1737    13756.1606
# 9brsa928sps_sapinhoa         24854.0247    12323.0419    24126.2471
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN    10021.0972    31289.2016
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               21892.0467           NaN     4214.0613
# 9ll19rjs_lula                22121.5773    22905.7604    23914.3750
# 9ll20drjs_lula               27244.6381    17736.4786    27492.6855
# 9ll2rjs_lula                 21777.7290    22109.4912    27928.3609
# 9ll6arjs_lula                       NaN           NaN           NaN
# 9ll7rjs_lula                 25007.3577    25219.2997    20450.6119
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2018_06  prod_2018_07  prod_2018_08
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN           NaN           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste      711.2949      693.0370      504.9356
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa1305arjs_mero           40975.2165    38846.0388    38577.1779
# 3brsa1350rjs_mero                   NaN           NaN           NaN
# 3brsa496rjs_lula             19201.1114    18361.9418     8779.3012
# 3brsa788sps_sapinhoa         20288.2610    22026.1444    22940.4320
# 3brsa821rjs_lula              6425.4644    10911.4175    11128.9070
# 3brsa830rjs_lula              9968.7335     9785.9828           NaN
# 3brsa839arjs_lula            21094.7851    21319.0462    22895.9576
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula            16348.0217     6990.5675           NaN
# 3brsa883rjs_lula             20134.6714    21921.5043    17734.7075
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8ll87drjs_lula               33712.1519    33488.4008    26807.2159
# 8lpa2dsps_lapa               17230.0959    17404.3527    17319.0202
# 8srr1arjs_sururu                    NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu          16109.0987     9332.5117     1595.7836
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula                    NaN           NaN        0.7436
# 9brsa908drjs_lula             7102.2727     6680.0087     4731.2235
# 9brsa928sps_sapinhoa         25250.3097    22351.3773    13561.8593
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios              32587.5664    29859.1118    24302.8012
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               10051.2931    18559.7068    24237.9594
# 9ll19rjs_lula                  174.1973           NaN           NaN
# 9ll20drjs_lula               27706.4638    28773.2396    28775.1491
# 9ll2rjs_lula                 24858.2009    17535.5583    23610.1937
# 9ll6arjs_lula                       NaN           NaN           NaN
# 9ll7rjs_lula                 25317.9550    24528.6581    23660.0620
# 9mrl231darjs_marlim                 NaN           NaN           NaN
# 9mrl231darjs_voador                 NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
# [179 rows x 32 columns]

# %% [markdown]
# ## Geo Data

# %% [markdown]
# Preprocessing the geo data is quite similar, but the data is within a different set of files. Let's use one of this file, which provides geospatial's wells coordinates (all the wells, including pre-salt... but beware!).

# %%
import pandas as pd

from unicodedata import normalize

data = pd.read_excel('../data/tabela_de_pocos_abril_2018.xlsx')

# %%
geo_df = pd.DataFrame(columns=['well', 'field', 'lat_4c', 'lon_4c', 'lat_dd', 'lon_dd'])
geo_df['well'] = data['POCO']
geo_df['field'] = data['CAMPO']
geo_df['lat_4c'] = data['LATITUDE_BASE_4C']
geo_df['lon_4c'] = data['LONGITUDE_BASE_4C']
geo_df['lat_dd'] = data['LATITUDE_BASE_DD']
geo_df['lon_dd'] = data['LONGITUDE_BASE_DD']

# Remove nan in well index.
geo_df = geo_df.drop(geo_df.loc[geo_df.well.isnull()].index, axis=0)
# Remove nan in field index.
geo_df = geo_df.drop(geo_df.loc[geo_df.field.isnull()].index, axis=0)

geo_df.well = geo_df.well.map(str.strip)
geo_df.well = geo_df.well.map(str.lower)
geo_df.field = geo_df.field.map(str.strip)
geo_df.field = geo_df.field.map(str.lower)

def normalize_str(input_str):
    return normalize('NFKD', input_str).encode('ascii', 'ignore').decode('utf-8')
geo_df.well = geo_df.well.map(normalize_str)
geo_df.field = geo_df.field.map(normalize_str)

def replace_str(input_str):
    return input_str.replace(' ', '').replace('-', '')
geo_df.well = geo_df.well.map(replace_str)
geo_df.field = geo_df.field.map(replace_str)

geo_df['index'] = geo_df.apply(lambda row: '%s_%s' % (row['well'], row['field']), axis=1)

geo_df = geo_df.drop('well', axis=1)
geo_df = geo_df.drop('field', axis=1)
geo_df = geo_df.set_index('index')

geo_df
# Out:
#                                    lat_4c         lon_4c          lat_dd  \
# index
# 7sz514se_siririzinho        -10:39:43,838  -37:05:51,689  -10,6621772222
# 7jub14hess_jubarte          -21:14:08,098  -40:01:42,932  -21,2355827777
# 7mll44hprjs_marlimleste     -22:26:39,475  -39:56:30,781  -22,4442986111
# 9fr18dprjs_frade            -21:53:27,749  -39:50:00,528  -21,8910413888
# 7mrl202hrjs_marlim          -22:24:25,011  -40:03:30,501     -22,4069475
# 7ba431dba_buracica          -12:11:45,136  -38:29:34,024  -12,1958711111
# 7fp398rn_fazendapocinho     -05:13:59,069  -36:30:45,334   -5,2330747222
# 7luc59hpam_lestedourucu     -04:52:20,399  -65:06:40,581   -4,8723330555
# 7mgp92dba_miranga           -12:20:29,345  -38:11:03,700  -12,3414847222
# 7fp377rn_fazendapocinho     -05:16:30,447  -36:36:37,187   -5,2751241666
# 7fp375rn_fazendapocinho     -05:16:27,047  -36:36:07,628   -5,2741797222
# 7fp376rn_fazendapocinho     -05:15:41,427  -36:34:10,168      -5,2615075
# 9mls96drjs_marlimsul        -22:38:43,118  -40:04:03,109  -22,6453105555
# 7fp382rn_fazendapocinho     -05:15:41,608  -36:34:23,151   -5,2615577777
# 1galp28se_doremi            -10:43:43,707  -37:01:22,190     -10,7288075
# 3brsa715drjs_papaterra      -23:29:37,925  -41:06:51,703  -23,4938680555
# 7arg753rn_altodorodrigues   -05:19:23,622  -36:44:15,539   -5,3232283333
# 7fp399rn_fazendapocinho     -05:14:02,277  -36:30:35,553   -5,2339658333
# 9urg5drjs_urugua            -24:19:27,915  -42:41:18,983  -24,3244208333
# 7fp372rn_fazendapocinho     -05:16:17,398  -36:36:27,498   -5,2714994444
# 1brsa707sps_mexilhao        -24:25:34,330  -44:16:27,705  -24,4262027777
# 7et1019rn_estreito          -05:22:54,620  -36:52:11,766   -5,3818388888
# 7ang5rn_angico              -05:24:03,415  -37:01:25,864   -5,4009486111
# 7et1002rn_estreito          -05:23:11,252  -36:51:58,874   -5,3864588888
# 7mxl9hpsps_mexilhao         -24:29:53,483  -44:12:17,449  -24,4981897222
# 7ag416dba_aguagrande        -12:20:58,509  -38:21:04,901  -12,3495858333
# 7sz524dse_siririzinho       -10:38:45,473  -37:04:38,036  -10,6459647222
# 4galp29rn_chopim            -05:08:37,278  -36:52:40,283   -5,1436883333
# 7cmn4hpaess_camarupimnorte  -19:52:07,740  -39:37:20,283  -19,8688166666
# 7lar12rn_lagoaaroeira       -05:13:08,061  -36:40:34,356   -5,2189058333
# ...                                   ...            ...             ...
# 7cam1049rn_cantodoamaro     -05:08:11,893  -37:15:18,868   -5,1366369444
# 7i69pba_itaparica           -12:54:04,104  -38:41:17,133       -12,90114
# 1brsa498sps_guaiama         -25:33:44,780  -45:35:05,885  -25,5624388888
# 4brsa613es_saomateusleste   -18:45:36,463  -39:46:10,835  -18,7601286111
# 8mll38hprjs_marlimleste     -22:27:14,350  -39:58:10,284  -22,4539861111
# 7mg57se_matogrosso          -10:41:27,352  -37:07:11,725  -10,6909311111
# 8cl55se_castanhal           -10:35:51,131  -37:05:03,895  -10,5975363888
# 7cam1223rn_cantodoamaro     -05:05:28,438  -37:11:03,234   -5,0912327777
# 8pc15pba_pojuca             -12:25:30,659  -38:20:20,984  -12,4251830555
# 7cam1204rn_cantodoamaro     -05:06:33,188  -37:11:40,281   -5,1092188888
# 4brsa465ess_canapu          -20:04:53,490  -39:17:36,906      -20,081525
# 7arg698rn_altodorodrigues   -05:18:57,479  -36:41:41,137   -5,3159663888
# 7arg700rn_altodorodrigues   -05:19:05,332  -36:43:02,500   -5,3181477777
# 9mls108drjs_marlimsul       -22:33:37,962  -40:01:29,939      -22,560545
# 7bi20des_barradoipiranga    -19:09:28,907  -39:44:02,483  -19,1580297222
# 7mgp60dba_miranga           -12:18:57,568  -38:11:31,601  -12,3159911111
# 7cam858rn_cantodoamaro      -05:08:34,041  -37:08:50,831   -5,1427891666
# 7cp9es_corregodaspedras     -18:52:05,702  -39:53:51,999  -18,8682505555
# 9mls68drjs_marlimsul        -22:31:51,634  -39:59:49,096  -22,5310094444
# 7arg654rn_altodorodrigues   -05:19:12,509  -36:43:14,695   -5,3201413888
# 7arg653rn_altodorodrigues   -05:19:05,968  -36:43:14,746   -5,3183244444
# 7ro66drjs_roncador          -21:56:31,017  -39:42:13,161  -21,9419491666
# 1brsa461es_jacutinga        -18:50:16,261  -39:53:31,083  -18,8378502777
# 3brsa460dses_tatui          -11:00:31,842  -37:03:53,182      -11,008845
# 8esp25hprjs_espadarte       -22:50:41,524  -40:20:35,574  -22,8448677777
# 7mp35dba_massape            -12:35:13,187  -38:25:57,882  -12,5869963888
# 7fmq32rn_fazendamalaquias   -05:21:12,001  -37:33:02,543   -5,3533336111
# 5brsa365ba_massape          -12:34:57,079  -38:24:56,069  -12,5825219444
# 7sz443se_siririzinho        -10:38:31,014  -37:06:19,115  -10,6419483333
# 7anb1dal_anambe             -09:44:20,093  -36:04:03,588   -9,7389147222
#
#                                     lon_dd
# index
# 7sz514se_siririzinho        -37,0976913888
# 7jub14hess_jubarte          -40,0285922222
# 7mll44hprjs_marlimleste     -39,9418836111
# 9fr18dprjs_frade                 -39,83348
# 7mrl202hrjs_marlim             -40,0584725
# 7ba431dba_buracica          -38,4927844444
# 7fp398rn_fazendapocinho     -36,5125927777
# 7luc59hpam_lestedourucu        -65,1112725
# 7mgp92dba_miranga           -38,1843611111
# 7fp377rn_fazendapocinho     -36,6103297222
# 7fp375rn_fazendapocinho     -36,6021188888
# 7fp376rn_fazendapocinho     -36,5694911111
# 9mls96drjs_marlimsul        -40,0675302777
# 7fp382rn_fazendapocinho        -36,5730975
# 1galp28se_doremi            -37,0228305555
# 3brsa715drjs_papaterra      -41,1143619444
# 7arg753rn_altodorodrigues   -36,7376497222
# 7fp399rn_fazendapocinho     -36,5098758333
# 9urg5drjs_urugua            -42,6886063888
# 7fp372rn_fazendapocinho     -36,6076383333
# 1brsa707sps_mexilhao           -44,2743625
# 7et1019rn_estreito              -36,869935
# 7ang5rn_angico              -37,0238511111
# 7et1002rn_estreito          -36,8663538888
# 7mxl9hpsps_mexilhao         -44,2048469444
# 7ag416dba_aguagrande        -38,3513613888
# 7sz524dse_siririzinho       -37,0772322222
# 4galp29rn_chopim            -36,8778563888
# 7cmn4hpaess_camarupimnorte  -39,6223008333
# 7lar12rn_lagoaaroeira            -36,67621
# ...                                    ...
# 7cam1049rn_cantodoamaro     -37,2552411111
# 7i69pba_itaparica              -38,6880925
# 1brsa498sps_guaiama         -45,5849680555
# 4brsa613es_saomateusleste   -39,7696763888
# 8mll38hprjs_marlimleste     -39,9695233333
# 7mg57se_matogrosso          -37,1199236111
# 8cl55se_castanhal           -37,0844152777
# 7cam1223rn_cantodoamaro     -37,1842316666
# 8pc15pba_pojuca             -38,3391622222
# 7cam1204rn_cantodoamaro        -37,1945225
# 4brsa465ess_canapu              -39,293585
# 7arg698rn_altodorodrigues   -36,6947602777
# 7arg700rn_altodorodrigues   -36,7173611111
# 9mls108drjs_marlimsul       -40,0249830555
# 7bi20des_barradoipiranga    -39,7340230555
# 7mgp60dba_miranga           -38,1921113888
# 7cam858rn_cantodoamaro      -37,1474530555
# 7cp9es_corregodaspedras        -39,8977775
# 9mls68drjs_marlimsul        -39,9969711111
# 7arg654rn_altodorodrigues   -36,7207486111
# 7arg653rn_altodorodrigues   -36,7207627777
# 7ro66drjs_roncador          -39,7036558333
# 1brsa461es_jacutinga           -39,8919675
# 3brsa460dses_tatui          -37,0647727777
# 8esp25hprjs_espadarte           -40,343215
# 7mp35dba_massape                -38,432745
# 7fmq32rn_fazendamalaquias   -37,5507063888
# 5brsa365ba_massape          -38,4155747222
# 7sz443se_siririzinho        -37,1053097222
# 7anb1dal_anambe             -36,0676633333
#
# [25044 rows x 4 columns]

# %% [markdown]
# Take a look in what we have:

# %%
geo_df
# Out:
#                                    lat_4c         lon_4c          lat_dd  \
# index
# 7sz514se_siririzinho        -10:39:43,838  -37:05:51,689  -10,6621772222
# 7jub14hess_jubarte          -21:14:08,098  -40:01:42,932  -21,2355827777
# 7mll44hprjs_marlimleste     -22:26:39,475  -39:56:30,781  -22,4442986111
# 9fr18dprjs_frade            -21:53:27,749  -39:50:00,528  -21,8910413888
# 7mrl202hrjs_marlim          -22:24:25,011  -40:03:30,501     -22,4069475
# 7ba431dba_buracica          -12:11:45,136  -38:29:34,024  -12,1958711111
# 7fp398rn_fazendapocinho     -05:13:59,069  -36:30:45,334   -5,2330747222
# 7luc59hpam_lestedourucu     -04:52:20,399  -65:06:40,581   -4,8723330555
# 7mgp92dba_miranga           -12:20:29,345  -38:11:03,700  -12,3414847222
# 7fp377rn_fazendapocinho     -05:16:30,447  -36:36:37,187   -5,2751241666
# 7fp375rn_fazendapocinho     -05:16:27,047  -36:36:07,628   -5,2741797222
# 7fp376rn_fazendapocinho     -05:15:41,427  -36:34:10,168      -5,2615075
# 9mls96drjs_marlimsul        -22:38:43,118  -40:04:03,109  -22,6453105555
# 7fp382rn_fazendapocinho     -05:15:41,608  -36:34:23,151   -5,2615577777
# 1galp28se_doremi            -10:43:43,707  -37:01:22,190     -10,7288075
# 3brsa715drjs_papaterra      -23:29:37,925  -41:06:51,703  -23,4938680555
# 7arg753rn_altodorodrigues   -05:19:23,622  -36:44:15,539   -5,3232283333
# 7fp399rn_fazendapocinho     -05:14:02,277  -36:30:35,553   -5,2339658333
# 9urg5drjs_urugua            -24:19:27,915  -42:41:18,983  -24,3244208333
# 7fp372rn_fazendapocinho     -05:16:17,398  -36:36:27,498   -5,2714994444
# 1brsa707sps_mexilhao        -24:25:34,330  -44:16:27,705  -24,4262027777
# 7et1019rn_estreito          -05:22:54,620  -36:52:11,766   -5,3818388888
# 7ang5rn_angico              -05:24:03,415  -37:01:25,864   -5,4009486111
# 7et1002rn_estreito          -05:23:11,252  -36:51:58,874   -5,3864588888
# 7mxl9hpsps_mexilhao         -24:29:53,483  -44:12:17,449  -24,4981897222
# 7ag416dba_aguagrande        -12:20:58,509  -38:21:04,901  -12,3495858333
# 7sz524dse_siririzinho       -10:38:45,473  -37:04:38,036  -10,6459647222
# 4galp29rn_chopim            -05:08:37,278  -36:52:40,283   -5,1436883333
# 7cmn4hpaess_camarupimnorte  -19:52:07,740  -39:37:20,283  -19,8688166666
# 7lar12rn_lagoaaroeira       -05:13:08,061  -36:40:34,356   -5,2189058333
# ...                                   ...            ...             ...
# 7cam1049rn_cantodoamaro     -05:08:11,893  -37:15:18,868   -5,1366369444
# 7i69pba_itaparica           -12:54:04,104  -38:41:17,133       -12,90114
# 1brsa498sps_guaiama         -25:33:44,780  -45:35:05,885  -25,5624388888
# 4brsa613es_saomateusleste   -18:45:36,463  -39:46:10,835  -18,7601286111
# 8mll38hprjs_marlimleste     -22:27:14,350  -39:58:10,284  -22,4539861111
# 7mg57se_matogrosso          -10:41:27,352  -37:07:11,725  -10,6909311111
# 8cl55se_castanhal           -10:35:51,131  -37:05:03,895  -10,5975363888
# 7cam1223rn_cantodoamaro     -05:05:28,438  -37:11:03,234   -5,0912327777
# 8pc15pba_pojuca             -12:25:30,659  -38:20:20,984  -12,4251830555
# 7cam1204rn_cantodoamaro     -05:06:33,188  -37:11:40,281   -5,1092188888
# 4brsa465ess_canapu          -20:04:53,490  -39:17:36,906      -20,081525
# 7arg698rn_altodorodrigues   -05:18:57,479  -36:41:41,137   -5,3159663888
# 7arg700rn_altodorodrigues   -05:19:05,332  -36:43:02,500   -5,3181477777
# 9mls108drjs_marlimsul       -22:33:37,962  -40:01:29,939      -22,560545
# 7bi20des_barradoipiranga    -19:09:28,907  -39:44:02,483  -19,1580297222
# 7mgp60dba_miranga           -12:18:57,568  -38:11:31,601  -12,3159911111
# 7cam858rn_cantodoamaro      -05:08:34,041  -37:08:50,831   -5,1427891666
# 7cp9es_corregodaspedras     -18:52:05,702  -39:53:51,999  -18,8682505555
# 9mls68drjs_marlimsul        -22:31:51,634  -39:59:49,096  -22,5310094444
# 7arg654rn_altodorodrigues   -05:19:12,509  -36:43:14,695   -5,3201413888
# 7arg653rn_altodorodrigues   -05:19:05,968  -36:43:14,746   -5,3183244444
# 7ro66drjs_roncador          -21:56:31,017  -39:42:13,161  -21,9419491666
# 1brsa461es_jacutinga        -18:50:16,261  -39:53:31,083  -18,8378502777
# 3brsa460dses_tatui          -11:00:31,842  -37:03:53,182      -11,008845
# 8esp25hprjs_espadarte       -22:50:41,524  -40:20:35,574  -22,8448677777
# 7mp35dba_massape            -12:35:13,187  -38:25:57,882  -12,5869963888
# 7fmq32rn_fazendamalaquias   -05:21:12,001  -37:33:02,543   -5,3533336111
# 5brsa365ba_massape          -12:34:57,079  -38:24:56,069  -12,5825219444
# 7sz443se_siririzinho        -10:38:31,014  -37:06:19,115  -10,6419483333
# 7anb1dal_anambe             -09:44:20,093  -36:04:03,588   -9,7389147222
#
#                                     lon_dd
# index
# 7sz514se_siririzinho        -37,0976913888
# 7jub14hess_jubarte          -40,0285922222
# 7mll44hprjs_marlimleste     -39,9418836111
# 9fr18dprjs_frade                 -39,83348
# 7mrl202hrjs_marlim             -40,0584725
# 7ba431dba_buracica          -38,4927844444
# 7fp398rn_fazendapocinho     -36,5125927777
# 7luc59hpam_lestedourucu        -65,1112725
# 7mgp92dba_miranga           -38,1843611111
# 7fp377rn_fazendapocinho     -36,6103297222
# 7fp375rn_fazendapocinho     -36,6021188888
# 7fp376rn_fazendapocinho     -36,5694911111
# 9mls96drjs_marlimsul        -40,0675302777
# 7fp382rn_fazendapocinho        -36,5730975
# 1galp28se_doremi            -37,0228305555
# 3brsa715drjs_papaterra      -41,1143619444
# 7arg753rn_altodorodrigues   -36,7376497222
# 7fp399rn_fazendapocinho     -36,5098758333
# 9urg5drjs_urugua            -42,6886063888
# 7fp372rn_fazendapocinho     -36,6076383333
# 1brsa707sps_mexilhao           -44,2743625
# 7et1019rn_estreito              -36,869935
# 7ang5rn_angico              -37,0238511111
# 7et1002rn_estreito          -36,8663538888
# 7mxl9hpsps_mexilhao         -44,2048469444
# 7ag416dba_aguagrande        -38,3513613888
# 7sz524dse_siririzinho       -37,0772322222
# 4galp29rn_chopim            -36,8778563888
# 7cmn4hpaess_camarupimnorte  -39,6223008333
# 7lar12rn_lagoaaroeira            -36,67621
# ...                                    ...
# 7cam1049rn_cantodoamaro     -37,2552411111
# 7i69pba_itaparica              -38,6880925
# 1brsa498sps_guaiama         -45,5849680555
# 4brsa613es_saomateusleste   -39,7696763888
# 8mll38hprjs_marlimleste     -39,9695233333
# 7mg57se_matogrosso          -37,1199236111
# 8cl55se_castanhal           -37,0844152777
# 7cam1223rn_cantodoamaro     -37,1842316666
# 8pc15pba_pojuca             -38,3391622222
# 7cam1204rn_cantodoamaro        -37,1945225
# 4brsa465ess_canapu              -39,293585
# 7arg698rn_altodorodrigues   -36,6947602777
# 7arg700rn_altodorodrigues   -36,7173611111
# 9mls108drjs_marlimsul       -40,0249830555
# 7bi20des_barradoipiranga    -39,7340230555
# 7mgp60dba_miranga           -38,1921113888
# 7cam858rn_cantodoamaro      -37,1474530555
# 7cp9es_corregodaspedras        -39,8977775
# 9mls68drjs_marlimsul        -39,9969711111
# 7arg654rn_altodorodrigues   -36,7207486111
# 7arg653rn_altodorodrigues   -36,7207627777
# 7ro66drjs_roncador          -39,7036558333
# 1brsa461es_jacutinga           -39,8919675
# 3brsa460dses_tatui          -37,0647727777
# 8esp25hprjs_espadarte           -40,343215
# 7mp35dba_massape                -38,432745
# 7fmq32rn_fazendamalaquias   -37,5507063888
# 5brsa365ba_massape          -38,4155747222
# 7sz443se_siririzinho        -37,1053097222
# 7anb1dal_anambe             -36,0676633333
#
# [25044 rows x 4 columns]

# %% [markdown]
# ## Merge Data
#
# Merging salt and geo data. The collision will retrieve only that is presented in both data bases.

# %%
merged_df = pd.concat([salt_df, geo_df], axis=1, join='inner')
merged_df
# Out:
#                            prod_2016_01  prod_2016_02  prod_2016_03  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN     4038.4289           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     3217.8084      940.7094     1039.1168
# 3brsa1053rjs_buzios           3444.0484    13159.8767       20.1903
# 3brsa1054drjs_marlimleste     3089.7979     3020.2906     3049.9899
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa496rjs_lula             21806.3831    21900.5478    22259.9048
# 3brsa788sps_sapinhoa         25972.5761    20186.7470    15274.7232
# 3brsa821rjs_lula                    NaN           NaN     2012.6820
# 3brsa830rjs_lula                    NaN           NaN           NaN
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# 3rjs0159rj_pampo                    NaN           NaN       10.3260
# 3rjs0168rj_linguado                 NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8jub39ess_jubarte             5144.4668     9265.9737     8217.4623
# 8ll37drjs_lula                      NaN           NaN           NaN
# 8ll50rjs_lula                       NaN           NaN      137.7306
# 8ll81drjs_lula                      NaN           NaN           NaN
# 8ll87drjs_lula                      NaN           NaN           NaN
# 9atp1rjs_atapu                 412.9565      395.4946           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             22103.1498    22207.9325    22361.7354
# 9brsa908drjs_lula            13856.5582    13533.3875    13417.0412
# 9brsa928sps_sapinhoa          6484.2449    10367.1932    24688.8344
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula                      NaN    24150.7969    32948.5508
# 9ll19rjs_lula                25174.7099    23005.6134     7030.1326
# 9ll20drjs_lula               27981.0206    22378.0029    26645.4111
# 9ll2rjs_lula                 28186.6944    33315.4448    29282.1853
# 9ll6arjs_lula                24746.3310    20402.5434    22622.2979
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_04  prod_2016_05  prod_2016_06  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN    16793.2997    19357.6807
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     1645.0457     1578.5540     1555.8059
# 3brsa1053rjs_buzios                 NaN     3389.5847           NaN
# 3brsa1054drjs_marlimleste      408.6213           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa496rjs_lula             10113.8224    18571.4009    21956.2511
# 3brsa788sps_sapinhoa         21989.9431    17651.8362    13338.3866
# 3brsa821rjs_lula                    NaN     4352.8143    11347.9087
# 3brsa830rjs_lula                    NaN    11202.3624    15316.2205
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# 3rjs0159rj_pampo                58.8881       55.4454      362.1243
# 3rjs0168rj_linguado                 NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8jub39ess_jubarte             9930.3191    10092.9507    10039.6413
# 8ll37drjs_lula                      NaN           NaN           NaN
# 8ll50rjs_lula                       NaN           NaN           NaN
# 8ll81drjs_lula                 367.8763           NaN           NaN
# 8ll87drjs_lula                      NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             12456.0433    14567.2424     9401.5409
# 9brsa908drjs_lula             8202.8515    13082.2245    13146.4325
# 9brsa928sps_sapinhoa          2116.2395    14485.2884    22314.0839
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               32196.6184    33494.9688    33015.3630
# 9ll19rjs_lula                 9255.1860    17353.1954     9670.4214
# 9ll20drjs_lula               30788.5424    20002.4287    28179.6468
# 9ll2rjs_lula                 31070.9978    30334.7783    34322.7501
# 9ll6arjs_lula                29061.8352    16222.2626    20648.8869
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_07  prod_2016_08  prod_2016_09  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN      222.1723           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia            17324.6283    19303.0414      421.0546
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     1554.5046     1668.1607     1594.7409
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa496rjs_lula             22511.5325    20002.4388    21239.8556
# 3brsa788sps_sapinhoa         20088.7421    20518.7056    24938.9971
# 3brsa821rjs_lula              2481.2793    13555.1659    14471.0598
# 3brsa830rjs_lula             16289.3414    18387.9566    20330.7717
# 3brsa839arjs_lula                   NaN           NaN           NaN
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN        0.0000        0.0000
# 3brsa865arjs_lula                   NaN           NaN           NaN
# 3brsa883rjs_lula                    NaN           NaN           NaN
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# 3rjs0159rj_pampo               338.8124      117.1430      350.8332
# 3rjs0168rj_linguado                 NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8jub39ess_jubarte            10224.8257    10503.4921     6859.5041
# 8ll37drjs_lula                      NaN           NaN           NaN
# 8ll50rjs_lula                       NaN           NaN           NaN
# 8ll81drjs_lula               22291.1374    30106.2709    30238.1966
# 8ll87drjs_lula                      NaN           NaN           NaN
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu                 NaN           NaN           NaN
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula             15153.1996    13150.3592    13689.8673
# 9brsa908drjs_lula            13195.8227    13082.7589    12874.5697
# 9brsa928sps_sapinhoa         27081.4678    22586.5081    22128.8557
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios               3759.2165    15098.0802    13195.5643
# 9buz7rjs_buzios                     NaN           NaN           NaN
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula               33048.6822    27500.6023    30051.4519
# 9ll19rjs_lula                16278.5025           NaN    15932.2978
# 9ll20drjs_lula               25707.6662    16705.1910    28589.3346
# 9ll2rjs_lula                 32292.9629    32333.3934    28995.9882
# 9ll6arjs_lula                17332.8491    15499.6369    27829.5765
# 9ll7rjs_lula                        NaN           NaN           NaN
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2016_10       ...        prod_2018_03  \
# 1brsa108aess_jubarte             0.0000       ...                 NaN
# 1brsa1116rjs_itapu               0.0000       ...                 NaN
# 1brsa1146rjs_atapu               0.0000       ...                 NaN
# 1brsa594sps_sapinhoa             0.0000       ...                 NaN
# 1brsa976rjs_sepia                0.0000       ...                 NaN
# 2anp1rjs_buzios                  0.0000       ...                 NaN
# 3brsa1017drjs_marlimleste     1728.0598       ...           2992.8340
# 3brsa1053rjs_buzios              0.0000       ...                 NaN
# 3brsa1054drjs_marlimleste        0.0000       ...                 NaN
# 3brsa1064rjs_buzios              0.0000       ...                 NaN
# 3brsa1132rjs_berbigao            0.0000       ...                 NaN
# 3brsa1172rjs_atapu               0.0000       ...                 NaN
# 3brsa1184rjs_buzios              0.0000       ...                 NaN
# 3brsa1201rjs_sepia               0.0000       ...                 NaN
# 3brsa1215rjs_itapu                  NaN       ...                 NaN
# 3brsa1243rjs_oestedeatapu        0.0000       ...                 NaN
# 3brsa496rjs_lula             15338.7192       ...          19839.9511
# 3brsa788sps_sapinhoa         23737.4376       ...          22012.1845
# 3brsa821rjs_lula              9567.5976       ...                 NaN
# 3brsa830rjs_lula              9219.2716       ...          10887.4580
# 3brsa839arjs_lula                   NaN       ...          13067.2893
# 3brsa854rjs_lula                 0.0000       ...                 NaN
# 3brsa861sps_lapa                 0.0000       ...                 NaN
# 3brsa865arjs_lula                   NaN       ...          17271.5823
# 3brsa883rjs_lula                    NaN       ...           3408.9104
# 3li0001rjs_linguado              0.0000       ...                 NaN
# 3pm0002rjs_pampo                 0.0000       ...                 NaN
# 3pm0003arjs_pampo                0.0000       ...                 NaN
# 3rjs0159rj_pampo               347.2245       ...                 NaN
# 3rjs0168rj_linguado              0.0000       ...                 NaN
# ...                                 ...       ...                 ...
# 8jub39ess_jubarte             9992.4241       ...          10075.7962
# 8ll37drjs_lula                      NaN       ...          19841.2590
# 8ll50rjs_lula                    0.0000       ...                 NaN
# 8ll81drjs_lula               29048.3255       ...          29066.8208
# 8ll87drjs_lula                      NaN       ...          30035.0603
# 9atp1rjs_atapu                      NaN       ...                 NaN
# 9atp3rjs_atapu                      NaN       ...                 NaN
# 9bbg1drjs_berbigao                  NaN       ...                 NaN
# 9brsa1191rjs_buzios              0.0000       ...                 NaN
# 9brsa1192sps_lapa                   NaN       ...                 NaN
# 9brsa1197rjs_buzios              0.0000       ...                 NaN
# 9brsa1212rjs_sururu                 NaN       ...          16835.6686
# 9brsa1254rjs_sepia               0.0000       ...                 NaN
# 9brsa1284rjs_atapu                  NaN       ...                 NaN
# 9brsa716rjs_lula              6158.8184       ...                 NaN
# 9brsa908drjs_lula            10880.6705       ...           8969.5635
# 9brsa928sps_sapinhoa         23042.3809       ...          24854.0247
# 9buz1rjs_buzios                  0.0000       ...                 NaN
# 9buz2rjs_buzios                  0.0000       ...                 NaN
# 9buz3rjs_buzios                  0.0000       ...                 NaN
# 9buz4rjs_buzios              14071.0070       ...                 NaN
# 9buz7rjs_buzios                     NaN       ...                 NaN
# 9buz8rjs_buzios                     NaN       ...                 NaN
# 9ll12drjs_lula               30394.3221       ...          21892.0467
# 9ll19rjs_lula                24999.0383       ...          22121.5773
# 9ll20drjs_lula               28668.0316       ...          27244.6381
# 9ll2rjs_lula                 29146.6555       ...          21777.7290
# 9ll6arjs_lula                28915.3956       ...                 NaN
# 9ll7rjs_lula                 20663.9268       ...          25007.3577
# 9sep1rjs_sepia                   0.0000       ...                 NaN
#
#                            prod_2018_04  prod_2018_05  prod_2018_06  \
# 1brsa108aess_jubarte                NaN           NaN           NaN
# 1brsa1116rjs_itapu                  NaN           NaN           NaN
# 1brsa1146rjs_atapu                  NaN           NaN           NaN
# 1brsa594sps_sapinhoa                NaN           NaN           NaN
# 1brsa976rjs_sepia                   NaN           NaN           NaN
# 2anp1rjs_buzios                     NaN           NaN           NaN
# 3brsa1017drjs_marlimleste     1745.1677      586.4773      711.2949
# 3brsa1053rjs_buzios                 NaN           NaN           NaN
# 3brsa1054drjs_marlimleste           NaN           NaN           NaN
# 3brsa1064rjs_buzios                 NaN           NaN           NaN
# 3brsa1132rjs_berbigao               NaN           NaN           NaN
# 3brsa1172rjs_atapu                  NaN           NaN           NaN
# 3brsa1184rjs_buzios                 NaN           NaN           NaN
# 3brsa1201rjs_sepia                  NaN           NaN           NaN
# 3brsa1215rjs_itapu                  NaN           NaN           NaN
# 3brsa1243rjs_oestedeatapu           NaN           NaN           NaN
# 3brsa496rjs_lula             23429.9532    22949.3915    19201.1114
# 3brsa788sps_sapinhoa         22799.8014    22446.9169    20288.2610
# 3brsa821rjs_lula               802.7104           NaN     6425.4644
# 3brsa830rjs_lula             13804.0623    17785.6288     9968.7335
# 3brsa839arjs_lula            24361.8760    20224.5773    21094.7851
# 3brsa854rjs_lula                    NaN           NaN           NaN
# 3brsa861sps_lapa                    NaN           NaN           NaN
# 3brsa865arjs_lula            17171.4966    16427.3555    16348.0217
# 3brsa883rjs_lula             20257.4403    20945.1907    20134.6714
# 3li0001rjs_linguado                 NaN           NaN           NaN
# 3pm0002rjs_pampo                    NaN           NaN           NaN
# 3pm0003arjs_pampo                   NaN           NaN           NaN
# 3rjs0159rj_pampo                    NaN           NaN           NaN
# 3rjs0168rj_linguado                 NaN           NaN           NaN
# ...                                 ...           ...           ...
# 8jub39ess_jubarte            10035.5042     9937.2377     8960.7975
# 8ll37drjs_lula               24688.6857    26135.4692    26408.7854
# 8ll50rjs_lula                       NaN           NaN           NaN
# 8ll81drjs_lula               29012.8900    23192.7185    27678.4745
# 8ll87drjs_lula               32568.6917    33990.6955    33712.1519
# 9atp1rjs_atapu                      NaN           NaN           NaN
# 9atp3rjs_atapu                      NaN           NaN           NaN
# 9bbg1drjs_berbigao                  NaN           NaN           NaN
# 9brsa1191rjs_buzios                 NaN           NaN           NaN
# 9brsa1192sps_lapa                   NaN           NaN           NaN
# 9brsa1197rjs_buzios                 NaN           NaN           NaN
# 9brsa1212rjs_sururu          16303.9633    16250.4201    16109.0987
# 9brsa1254rjs_sepia                  NaN           NaN           NaN
# 9brsa1284rjs_atapu                  NaN           NaN           NaN
# 9brsa716rjs_lula                    NaN           NaN           NaN
# 9brsa908drjs_lula            12851.1737    13756.1606     7102.2727
# 9brsa928sps_sapinhoa         12323.0419    24126.2471    25250.3097
# 9buz1rjs_buzios                     NaN           NaN           NaN
# 9buz2rjs_buzios                     NaN           NaN           NaN
# 9buz3rjs_buzios                     NaN           NaN           NaN
# 9buz4rjs_buzios                     NaN           NaN           NaN
# 9buz7rjs_buzios              10021.0972    31289.2016    32587.5664
# 9buz8rjs_buzios                     NaN           NaN           NaN
# 9ll12drjs_lula                      NaN     4214.0613    10051.2931
# 9ll19rjs_lula                22905.7604    23914.3750      174.1973
# 9ll20drjs_lula               17736.4786    27492.6855    27706.4638
# 9ll2rjs_lula                 22109.4912    27928.3609    24858.2009
# 9ll6arjs_lula                       NaN           NaN           NaN
# 9ll7rjs_lula                 25219.2997    20450.6119    25317.9550
# 9sep1rjs_sepia                      NaN           NaN           NaN
#
#                            prod_2018_07  prod_2018_08         lat_4c  \
# 1brsa108aess_jubarte                NaN           NaN  -21:16:23,421
# 1brsa1116rjs_itapu                  NaN           NaN  -24:48:06,173
# 1brsa1146rjs_atapu                  NaN           NaN  -24:58:31,873
# 1brsa594sps_sapinhoa                NaN           NaN  -25:48:23,679
# 1brsa976rjs_sepia                   NaN           NaN  -25:13:24,333
# 2anp1rjs_buzios                     NaN           NaN  -24:37:47,228
# 3brsa1017drjs_marlimleste      693.0370      504.9356  -22:26:42,313
# 3brsa1053rjs_buzios                 NaN           NaN  -24:47:08,864
# 3brsa1054drjs_marlimleste           NaN           NaN  -22:31:11,227
# 3brsa1064rjs_buzios                 NaN           NaN  -24:41:42,544
# 3brsa1132rjs_berbigao               NaN           NaN  -24:59:26,922
# 3brsa1172rjs_atapu                  NaN           NaN  -24:55:36,121
# 3brsa1184rjs_buzios                 NaN           NaN  -24:39:55,197
# 3brsa1201rjs_sepia                  NaN           NaN  -25:14:30,156
# 3brsa1215rjs_itapu                  NaN           NaN  -24:44:27,895
# 3brsa1243rjs_oestedeatapu           NaN           NaN  -24:56:53,233
# 3brsa496rjs_lula             18361.9418     8779.3012  -25:34:20,263
# 3brsa788sps_sapinhoa         22026.1444    22940.4320  -25:41:15,092
# 3brsa821rjs_lula             10911.4175    11128.9070  -25:26:22,753
# 3brsa830rjs_lula              9785.9828           NaN  -25:13:15,413
# 3brsa839arjs_lula            21319.0462    22895.9576  -25:08:25,537
# 3brsa854rjs_lula                    NaN           NaN  -25:37:58,525
# 3brsa861sps_lapa                    NaN           NaN  -25:31:41,867
# 3brsa865arjs_lula             6990.5675           NaN  -25:27:02,267
# 3brsa883rjs_lula             21921.5043    17734.7075  -25:36:58,307
# 3li0001rjs_linguado                 NaN           NaN  -22:45:03,031
# 3pm0002rjs_pampo                    NaN           NaN  -22:47:39,414
# 3pm0003arjs_pampo                   NaN           NaN  -22:48:13,157
# 3rjs0159rj_pampo                    NaN           NaN  -22:49:34,278
# 3rjs0168rj_linguado                 NaN           NaN  -22:44:26,508
# ...                                 ...           ...            ...
# 8jub39ess_jubarte             9895.8654     9860.5818  -21:14:02,224
# 8ll37drjs_lula               26307.0303    26229.4163  -25:08:53,659
# 8ll50rjs_lula                       NaN           NaN  -25:33:57,463
# 8ll81drjs_lula               29070.6292    26508.6157  -25:28:44,089
# 8ll87drjs_lula               33488.4008    26807.2159  -25:26:48,802
# 9atp1rjs_atapu                      NaN           NaN  -24:57:14,912
# 9atp3rjs_atapu                      NaN           NaN  -24:57:23,016
# 9bbg1drjs_berbigao                  NaN           NaN  -25:01:48,823
# 9brsa1191rjs_buzios                 NaN           NaN  -24:39:41,168
# 9brsa1192sps_lapa                   NaN           NaN  -25:35:44,100
# 9brsa1197rjs_buzios                 NaN           NaN  -24:44:55,628
# 9brsa1212rjs_sururu           9332.5117     1595.7836  -25:00:53,847
# 9brsa1254rjs_sepia                  NaN           NaN  -25:14:37,432
# 9brsa1284rjs_atapu                  NaN           NaN  -24:59:46,937
# 9brsa716rjs_lula                    NaN        0.7436  -25:32:44,438
# 9brsa908drjs_lula             6680.0087     4731.2235  -25:30:43,983
# 9brsa928sps_sapinhoa         22351.3773    13561.8593  -25:46:22,984
# 9buz1rjs_buzios                     NaN           NaN  -24:43:07,385
# 9buz2rjs_buzios                     NaN           NaN  -24:47:31,357
# 9buz3rjs_buzios                     NaN           NaN  -24:48:49,016
# 9buz4rjs_buzios                     NaN           NaN  -24:37:46,921
# 9buz7rjs_buzios              29859.1118    24302.8012  -24:37:45,562
# 9buz8rjs_buzios                     NaN           NaN  -24:42:10,517
# 9ll12drjs_lula               18559.7068    24237.9594  -25:26:57,834
# 9ll19rjs_lula                       NaN           NaN  -25:21:15,664
# 9ll20drjs_lula               28773.2396    28775.1491  -25:10:09,757
# 9ll2rjs_lula                 17535.5583    23610.1937  -25:11:14,089
# 9ll6arjs_lula                       NaN           NaN  -25:09:17,382
# 9ll7rjs_lula                 24528.6581    23660.0620  -25:31:45,024
# 9sep1rjs_sepia                      NaN           NaN  -25:13:06,748
#
#                                   lon_4c          lat_dd          lon_dd
# 1brsa108aess_jubarte       -40:00:11,994     -21,2731725  -40,0033316666
# 1brsa1116rjs_itapu         -42:42:13,712  -24,8017147222  -42,7038088888
# 1brsa1146rjs_atapu         -42:26:18,323  -24,9755202777  -42,4384230555
# 1brsa594sps_sapinhoa       -43:13:31,011     -25,8065775  -43,2252808333
# 1brsa976rjs_sepia          -42:31:25,561  -25,2234258333  -42,5237669444
# 2anp1rjs_buzios            -42:29:27,263  -24,6297855555  -42,4909063888
# 3brsa1017drjs_marlimleste  -39:57:13,187  -22,4450869444  -39,9536630555
# 3brsa1053rjs_buzios        -42:28:33,522  -24,7857955555  -42,4759783333
# 3brsa1054drjs_marlimleste  -39:55:13,746  -22,5197852777      -39,920485
# 3brsa1064rjs_buzios        -42:28:02,768  -24,6951511111  -42,4674355555
# 3brsa1132rjs_berbigao      -42:40:23,020  -24,9908116666  -42,6730611111
# 3brsa1172rjs_atapu         -42:28:59,880  -24,9267002777        -42,4833
# 3brsa1184rjs_buzios        -42:25:36,097     -24,6653325  -42,4266936111
# 3brsa1201rjs_sepia         -42:32:39,248       -25,24171  -42,5442355555
# 3brsa1215rjs_itapu         -42:42:19,863  -24,7410819444     -42,7055175
# 3brsa1243rjs_oestedeatapu  -42:30:44,835  -24,9481202777  -42,5124541666
# 3brsa496rjs_lula           -42:49:45,587  -25,5722952777  -42,8293297222
# 3brsa788sps_sapinhoa       -43:10:31,154  -25,6875255555  -43,1753205555
# 3brsa821rjs_lula           -42:43:13,166  -25,4396536111  -42,7203238888
# 3brsa830rjs_lula           -42:53:20,585  -25,2209480555  -42,8890513888
# 3brsa839arjs_lula          -42:54:13,024  -25,1404269444  -42,9036177777
# 3brsa854rjs_lula           -42:55:00,139  -25,6329236111  -42,9167052777
# 3brsa861sps_lapa           -43:26:18,327  -25,5282963888  -43,4384241666
# 3brsa865arjs_lula          -42:55:00,237  -25,4506297222     -42,9167325
# 3brsa883rjs_lula           -42:47:35,041  -25,6161963888  -42,7930669444
# 3li0001rjs_linguado        -40:48:36,567  -22,7508419444     -40,8101575
# 3pm0002rjs_pampo           -40:45:37,293  -22,7942816666  -40,7603591666
# 3pm0003arjs_pampo          -40:45:44,461  -22,8036547222  -40,7623502777
# 3rjs0159rj_pampo           -40:47:05,711  -22,8261883333  -40,7849197222
# 3rjs0168rj_linguado        -40:49:20,806  -22,7406966666  -40,8224461111
# ...                                  ...             ...             ...
# 8jub39ess_jubarte          -39:59:43,491  -21,2339511111  -39,9954141666
# 8ll37drjs_lula             -42:53:42,217  -25,1482386111  -42,8950602777
# 8ll50rjs_lula              -42:47:04,649  -25,5659619444  -42,7846247222
# 8ll81drjs_lula             -42:48:13,159  -25,4789136111  -42,8036552777
# 8ll87drjs_lula             -42:42:54,121  -25,4468894444  -42,7150336111
# 9atp1rjs_atapu             -42:29:33,582  -24,9541422222  -42,4926616666
# 9atp3rjs_atapu             -42:26:12,188  -24,9563933333  -42,4367188888
# 9bbg1drjs_berbigao         -42:39:10,583  -25,0302286111  -42,6529397222
# 9brsa1191rjs_buzios        -42:28:46,216  -24,6614355555  -42,4795044444
# 9brsa1192sps_lapa          -43:31:31,098  -25,5955833333      -43,525305
# 9brsa1197rjs_buzios        -42:28:07,466  -24,7487855555  -42,4687405555
# 9brsa1212rjs_sururu        -42:36:29,839     -25,0149575  -42,6082886111
# 9brsa1254rjs_sepia         -42:31:36,833  -25,2437311111  -42,5268980555
# 9brsa1284rjs_atapu         -42:25:16,872  -24,9963713888  -42,4213533333
# 9brsa716rjs_lula           -42:48:20,476  -25,5456772222  -42,8056877777
# 9brsa908drjs_lula          -42:48:58,102     -25,5122175  -42,8161394444
# 9brsa928sps_sapinhoa       -43:13:06,477  -25,7730511111  -43,2184658333
# 9buz1rjs_buzios            -42:28:43,452  -24,7187180555  -42,4787366666
# 9buz2rjs_buzios            -42:28:10,963  -24,7920436111  -42,4697119444
# 9buz3rjs_buzios            -42:29:21,273  -24,8136155555     -42,4892425
# 9buz4rjs_buzios            -42:26:58,790  -24,6297002777  -42,4496638888
# 9buz7rjs_buzios            -42:31:10,976  -24,6293227777  -42,5197155555
# 9buz8rjs_buzios            -42:30:40,376  -24,7029213888  -42,5112155555
# 9ll12drjs_lula             -42:46:52,335  -25,4493983333  -42,7812041666
# 9ll19rjs_lula              -42:37:55,219  -25,3543511111  -42,6320052777
# 9ll20drjs_lula             -42:55:32,217  -25,1693769444  -42,9256158333
# 9ll2rjs_lula               -42:55:14,948  -25,1872469444  -42,9208188888
# 9ll6arjs_lula              -42:57:50,855  -25,1548283333  -42,9641263888
# 9ll7rjs_lula               -42:44:50,313  -25,5291733333  -42,7473091666
# 9sep1rjs_sepia             -42:32:46,961  -25,2185411111  -42,5463780555
#
# [134 rows x 36 columns]

# %% [markdown]
# # Visualization in a Folium Map

# %% [markdown]
# The details of building the map are skipped. In short words, is a function with a collection of option. We use Altair and its VegaLite integration to put some statistics' plot over the map.
#
# Sounds interesting? Let's see the result!

# %%
def show_map(period, show_production, show_heatmap, show_history, show_fields, shp_name):
    import folium
    import branca
    import json

    import numpy as np
    import altair.vegalite.v1 as alt

    from folium.plugins import HeatMap
    tiles = 'http://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
    attr = ('Tiles &copy; Esri &mdash; Sources: GEBCO, NOAA, CHS, OSU, UNH, CSUMB, National Geographic, DeLorme, NAVTEQ, and Esri')

    m = folium.Map(
        location=[-23.5, -41.5],
        tiles=tiles,
        attr=attr,
        zoom_start=7,
    )

    group = folium.FeatureGroup('geo_data')

    production = merged_df[period]
    lat = merged_df.lat_dd.values
    lon = merged_df.lon_dd.values

    max_prod = np.nanmax(production)
    
    months = merged_df.columns.tolist()[:-4]
    months = [x.replace('_', '-').replace('prod-', '') + '-01' for x in months]
    
    merged_df_geo_dropped = merged_df.iloc[:, :-4].copy()

    colorscale = branca.colormap.linear.Oranges_08.scale(production.min(), production.max())

    for prod, geo in zip(production, zip(lat, lon)):
        if np.isnan(prod):
            continue

        latitude, longitude = float(geo[0].replace(',', '.')), float(geo[1].replace(',', '.'))
        location = [latitude, longitude]
        message = 'Production: %s' % str(prod)
        well_name = merged_df[(merged_df['lat_dd'] == geo[0]) & (merged_df['lon_dd'] == geo[1])].index[0]

        if show_production:
            folium.Circle(
                location=location,
                popup=message,
                radius=(prod/max_prod)*2500,
                color=colorscale(prod),
                fill=True,
                fill_color=colorscale(prod),
            ).add_to(group)
            
        if show_history:
            plot_points = {
                'Month': months,
                'Production (bbl/day)': merged_df_geo_dropped.loc[well_name].fillna(0).values,
                'Well': well_name.upper()
            }

            data_df = pd.DataFrame(plot_points)
            chart = alt.Chart(data_df).mark_bar().encode(
                x='Month:O',
                y='Production (bbl/day)',
                color='Well:N'
            )

            marker = folium.Marker(location=location)
            popup = folium.Popup(max_width=750)
            folium.VegaLite(chart, width="60%", height="100%").add_to(popup)

            popup.add_to(marker)
            marker.add_to(group)
            
    if show_fields:
        import geopandas as gp
        fp = '%s.shp' % shp_name
        data = gp.read_file(fp)
        data_range = data.shape[0]
        for i in range(data_range):
            shp_plot = folium.GeoJson(
            data.iloc[i:i+1],
            name=(u'Campo: %s' %  data['NOM_CAMPO'][i].lower()), 
            style_function=lambda feature: {
                'fillColor': 'red',
                'color': 'black',
                'weight': 2,
                'dashArray': '5, 5'
                }
            )
            label = '%s' % data['NOM_CAMPO'][i]
            folium.Popup(label).add_to(shp_plot)
            shp_plot.add_to(m)

    if show_heatmap:
        heat_data = [[float(geo[0].replace(',', '.')), float(geo[1].replace(',', '.')), float(prod) / production.max()] for prod, geo in zip(production, zip(lat, lon)) if prod > 0.0]
        HeatMap(
            heat_data,
            max_zoom=1,
            min_opacity=0.2,
            blur=25
        ).add_to(m)

    group.add_to(m)

    return m

# %%
from ipywidgets import interact, Layout, Box

values = [column for column in merged_df.iloc[:, :-4].columns]

# %%
interactive_map = interact(show_map, period=values, show_production=False, show_heatmap=False, show_history=False, show_fields=False, shp_name='../Campos/Campos_de_Producao')
# Out:
# interactive(children=(Dropdown(description='period', options=('prod_2016_01', 'prod_2016_02', 'prod_2016_03', …

# %% [markdown]
# # Exploring the data
#
# Now let's dive-in more in the data and its main properties to Petroleum Engineers.
#
# We want to answer:
#
# * What is going on with the pre-salt production? Increasing? Decreasing?
#
# * Could we list the best wells over a rank?
#
# * How is distributed the pre-salt production in a month?
#
# * All wells are given good production rate?

# %% [markdown]
# ### Importing libs we will use

# %%
import altair as alt
import seaborn as sb
import matplotlib.pyplot as plt

alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %% [markdown]
# Pre-salt overall production by months

# %%
months = merged_df.columns.tolist()[:-4]
months = [x.replace('_', '-').replace('prod-', '') + '-01' for x in months]
month_production = []
for column in merged_df.iloc[:, :-4].columns:
    month_production.append(merged_df[column].sum())

plot_df = pd.DataFrame(columns=['Month', 'Pre-salt Production (bbl/day)'])
plot_df['Month'] = months
plot_df['Pre-salt Production (bbl/day)'] = month_production
chart = alt.Chart(plot_df).mark_bar().encode(
    x='Month:T',
    y='Pre-salt Production (bbl/day)'
).interactive()

chart

# %% [markdown]
# ### Overall pre-salt production histogram by month

# %%
def Freedman_Diaconis_bins_row(df_row):
    """
    Compute the bins number according to Freedman-Diaconis h parameter
    """
    quartile_1 = df_row.quantile(0.25)
    quartile_3 = df_row.quantile(0.75)
    IQR = quartile_3 - quartile_1
    n = len(df_row)
    h = int(2 * IQR / (n ** (1. / 3.)))
    max_df_value = df_row.max()
    min_df_value = df_row.min()
    bins = int((max_df_value - min_df_value) / h) + 1
    bins = 8
    
    return bins

def hist_plot_by_month(period):
    target_df = merged_df.T.iloc[:-4,:].loc[period].copy()

    bins = Freedman_Diaconis_bins_row(target_df)
    plt.xlabel('Production (bbl/day)')
    target_df.plot.hist(bins=bins)

# %%
from ipywidgets import interact

months = [column for column in merged_df.iloc[:, :-4].columns]

interact(hist_plot_by_month, period=months)
# Out:
# interactive(children=(Dropdown(description='period', options=('prod_2016_01', 'prod_2016_02', 'prod_2016_03', …
# <function __main__.hist_plot_by_month(period)>

# %% [markdown]
# ### Plotting best wells ranked in terms of production in a given month

# %%
def bar_plot_by_month(period, rank_lim):
    best_wells_df = merged_df.iloc[:, :-4].sort_values(by=period, ascending=False)

    df_collection = {}
    for column in merged_df.iloc[:, :-4].columns:
        df_collection[column] = merged_df[column]

    plot_df = pd.DataFrame(columns=['Well', 'Production (bbl/day)'])
    plot_df['Production (bbl/day)'] = df_collection[period].sort_values(ascending=False)[:rank_lim]
    plot_df['Well'] = df_collection[period].sort_values(ascending=False)[:rank_lim].index.map(str.upper)
    plot_df.index = range(len(plot_df))

    sb.set()
    fig, ax = plt.subplots()
    bar_plot = sb.barplot(x=plot_df['Well'], y=plot_df['Production (bbl/day)'], ax=ax)
    bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=90)
    Fig = bar_plot.get_figure()

# %%
from ipywidgets import interact, IntSlider

months = [column for column in merged_df.iloc[:, :-4].columns]

interact(bar_plot_by_month, period=months, rank_lim=IntSlider(min=5, max=20, value=10))
# Out:
# interactive(children=(Dropdown(description='period', options=('prod_2016_01', 'prod_2016_02', 'prod_2016_03', …
# <function __main__.bar_plot_by_month(period, rank_lim)>

# %% [markdown]
# ### How much dispersed is well production data? Box plot could tell to us!

# %%
def box_plot_by_month(period, rank_lim):
    target_df = merged_df.copy().sort_values(by=period, ascending=False).T.iloc[:-4,:rank_lim].replace({'0':np.nan, 0:np.nan}).copy()
    
    sb.set()
    fig, ax = plt.subplots()

    box_plot = sb.boxplot(
        palette=["m", "g"],
        data=target_df,
        orient='h',
        ax=ax
    )
    sb.despine(offset=10, trim=True)

# %%
from ipywidgets import interact, IntSlider

months = [column for column in merged_df.iloc[:, :-4].columns]

interact(box_plot_by_month, period=months, rank_lim=IntSlider(min=1, max=15, value=10))
# Out:
# interactive(children=(Dropdown(description='period', options=('prod_2016_01', 'prod_2016_02', 'prod_2016_03', …
# <function __main__.box_plot_by_month(period, rank_lim)>

# %% [markdown]
# # Like presalt production, this is just the beginning...
#
# * Do you like to contribute?
#
# * Do you think it's interesting?
#
# * Learn something new?
#
# * If you say yes to any question above, we met our main objective!

# %% [markdown]
# # Thank you! Questions?
#
# <p align="center">
#   <img src=img/pybr14.png" width="400"/></p>
#                                       <img src=img/esss_2_pos_RGB.jpg" width="400"/></p>
